# %%
import pandas as pd
import numpy as np
Dict1 = {'Name':['Mohit','Rohit','hitesh','Kedar','Sushil','Roshan'],
         'Marks':[92,89,78,74,45,56],
         'City':['Mumbai','Pune','Gondia','Amgaon','Bhandara','Amgaon']}

# %%
df=pd.DataFrame(Dict1)

# %%
df
# Out:
#      Name  Marks      City
# 0   Mohit     92    Mumbai
# 1   Rohit     89      Pune
# 2  hitesh     78    Gondia
# 3   Kedar     74    Amgaon
# 4  Sushil     45  Bhandara
# 5  Roshan     56    Amgaon

# %%
df.to_csv('Friends.csv')

# %%
df.to_csv('Friends_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#     Name  Marks    City
# 0  Mohit     92  Mumbai
# 1  Rohit     89    Pune

# %%
df.tail(2)
# Out:
#      Name  Marks      City
# 4  Sushil     45  Bhandara
# 5  Roshan     56    Amgaon

# %%
df.describe()
# Out:
#            Marks
# count   6.000000
# mean   72.333333
# std    18.511258
# min    45.000000
# 25%    60.500000
# 50%    76.000000
# 75%    86.250000
# max    92.000000

# %%
data=pd.read_csv('adult.csv')

# %%
data.head(3)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0              NaN  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
# 2              NaN      Unmarried  Black  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K

# %%
data['education'][5]='HS-grad'
# Out:
# C:\Users\xmrmo\AppData\Local\Temp\ipykernel_13368\1220936908.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['education'][5]='HS-grad'
# C:\Users\xmrmo\AppData\Local\Temp\ipykernel_13368\1220936908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['education'][5]='HS-grad'

# %%
data.head(6)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K

# %%
data.to_csv('try.csv')

# %%
df.index=['First','Second','Third','Fourth','Fifth','Sixth']

# %%
df
# Out:
#           Name  Marks      City
# First    Mohit     92    Mumbai
# Second   Rohit     89      Pune
# Third   hitesh     78    Gondia
# Fourth   Kedar     74    Amgaon
# Fifth   Sushil     45  Bhandara
# Sixth   Roshan     56    Amgaon

# %%
ser=pd.Series(np.random.rand(20))

# %%
ser
# Out:
# 0     0.940753
# 1     0.516758
# 2     0.113889
# 3     0.549945
# 4     0.981644
# 5     0.686548
# 6     0.192866
# 7     0.559730
# 8     0.411379
# 9     0.866752
# 10    0.215894
# 11    0.780859
# 12    0.863549
# 13    0.949780
# 14    0.540880
# 15    0.059743
# 16    0.024068
# 17    0.418736
# 18    0.368340
# 19    0.491141
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,
py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][1]=4566

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0      9874  0.096088  0.971471  0.403590  0.981621
# 1  0.285339  0.927405  0.327143  0.878831  0.578229

# %%
newdf2.head(2)
# Out:
#       0         1         2         3         4
# 0  9874  0.096088  0.971471  0.403590  0.981621
# 1  4566  0.927405  0.327143  0.878831  0.578229

# %%
newdf2.columns=list("ABCDE")

# %%
newdf2.head(2)
# Out:
#       A         B         C         D         E
# 0  9874  0.096088  0.971471  0.403590  0.981621
# 1  4566  0.927405  0.327143  0.878831  0.578229

# %%
newdf2.loc[0,0]=0

# %%
newdf2.loc[0,'A']=0

# %%
newdf2.head(2)
# Out:
#       A         B         C         D         E    0
# 0     0  0.096088  0.971471  0.403590  0.981621  0.0
# 1  4566  0.927405  0.327143  0.878831  0.578229  NaN

# %%
newdf2=newdf2.drop(0,axis=1)

# %%
newdf2.head()
# Out:
#           A         B         C         D         E
# 0         0  0.096088  0.971471  0.403590  0.981621
# 1      4566  0.927405  0.327143  0.878831  0.578229
# 2  0.214779  0.772924  0.950085  0.309509  0.171094
# 3  0.513156  0.411196  0.242260  0.120732  0.698364
# 4  0.557123  0.927283  0.684800  0.824064  0.364643

# %%
newdf2.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.327143  0.878831
# 2  0.950085  0.309509

# %%
newdf2.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1      4566  0.927405  0.327143  0.878831  0.578229
# 2  0.214779  0.772924  0.950085  0.309509  0.171094

# %%
newdf2.loc[:,['C','E']]
# Out:
#             C         E
# 0    0.971471  0.981621
# 1    0.327143  0.578229
# 2    0.950085  0.171094
# 3    0.242260  0.698364
# 4    0.684800  0.364643
# ..        ...       ...
# 329  0.261147  0.337543
# 330  0.587014  0.925027
# 331  0.199518  0.485662
# 332  0.257479  0.831652
# 333  0.941692  0.998994
#
# [334 rows x 2 columns]

# %%
newdf2.loc[(newdf2['A']<0.3)]
# Out:
#             A         B         C         D         E
# 0           0  0.096088  0.971471  0.403590  0.981621
# 2    0.214779  0.772924  0.950085  0.309509  0.171094
# 10   0.228063  0.088000  0.406982  0.714703  0.906647
# 11   0.046054  0.935651  0.719635  0.199643  0.035047
# 14   0.298493  0.744959  0.098805  0.727762  0.039684
# ..        ...       ...       ...       ...       ...
# 313  0.190329  0.604055  0.445851  0.201901  0.289666
# 319  0.272703  0.425093  0.811956  0.590539  0.066435
# 326  0.037358  0.607781  0.040353  0.678499  0.632230
# 330  0.098507  0.729945  0.587014  0.664138  0.925027
# 332  0.074304  0.264164  0.257479  0.956436  0.831652
#
# [101 rows x 5 columns]

# %%
newdf2.loc[(newdf2['A']<0.3) & (newdf2['C']>0.1)]
# Out:
#             A         B         C         D         E
# 0           0  0.096088  0.971471  0.403590  0.981621
# 2    0.214779  0.772924  0.950085  0.309509  0.171094
# 10   0.228063  0.088000  0.406982  0.714703  0.906647
# 11   0.046054  0.935651  0.719635  0.199643  0.035047
# 19   0.101415  0.708481  0.834580  0.078282  0.046006
# ..        ...       ...       ...       ...       ...
# 305  0.293824  0.177306  0.413787  0.215571  0.537476
# 313  0.190329  0.604055  0.445851  0.201901  0.289666
# 319  0.272703  0.425093  0.811956  0.590539  0.066435
# 330  0.098507  0.729945  0.587014  0.664138  0.925027
# 332  0.074304  0.264164  0.257479  0.956436  0.831652
#
# [89 rows x 5 columns]

# %%
newdf2.iloc[0,4]
#index counting
# Out:
# np.float64(0.981620825310079)

# %%
newdf2.iloc[[0,5],[1,4]]
# Out:
#           B         E
# 0  0.096088  0.981621
# 5  0.239353  0.442190
