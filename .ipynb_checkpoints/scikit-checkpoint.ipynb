# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\xmrmo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/11.1 MB 1.0 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/11.1 MB 1.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.1 MB 1.4 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.1 MB 1.5 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.1 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/11.1 MB 1.0 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/11.1 MB 1.0 MB/s eta 0:00:08
#    ------------- -------------------------- 3.7/11.1 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 3.9/11.1 MB 1.1 MB/s eta 0:00:07
#    --------------- ------------------------ 4.2/11.1 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.5/11.1 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.7/11.1 MB 1.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.7/11.1 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.0/11.1 MB 1.0 MB/s eta 0:00:05
#    --------------------- ------------------ 6.0/11.1 MB 1.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.3/11.1 MB 1.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.6/11.1 MB 1.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.6/11.1 MB 1.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.6/11.1 MB 1.0 MB/s eta 0:00:05
#    ------------------------ --------------- 6.8/11.1 MB 959.8 kB/s eta 0:00:05
#    ------------------------- -------------- 7.1/11.1 MB 978.0 kB/s eta 0:00:05
#    --------------------------- ------------ 7.6/11.1 MB 1.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 7.9/11.1 MB 1.0 MB/s eta 0:00:04
#    ----------------------------- ---------- 8.1/11.1 MB 1.0 MB/s eta 0:00:03
#    ------------------------------ --------- 8.4/11.1 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 8.7/11.1 MB 1.1 MB/s eta 0:00:03
#    --------------------------------- ------ 9.2/11.1 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.7/11.1 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 10.2/11.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.1 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 1.2 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.1-cp312-cp312-win_amd64.whl (43.6 MB)
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/43.6 MB ? eta -:--:--
#    ---------------------------------------- 0.5/43.6 MB 985.5 kB/s eta 0:00:44
#     --------------------------------------- 0.8/43.6 MB 1.2 MB/s eta 0:00:38
#     --------------------------------------- 1.0/43.6 MB 1.1 MB/s eta 0:00:39
#    - -------------------------------------- 1.6/43.6 MB 1.5 MB/s eta 0:00:29
#    - -------------------------------------- 1.8/43.6 MB 1.6 MB/s eta 0:00:27
#    - -------------------------------------- 2.1/43.6 MB 1.5 MB/s eta 0:00:28
#    -- ------------------------------------- 2.4/43.6 MB 1.4 MB/s eta 0:00:30
#    -- ------------------------------------- 2.6/43.6 MB 1.4 MB/s eta 0:00:30
#    -- ------------------------------------- 3.1/43.6 MB 1.5 MB/s eta 0:00:28
#    --- ------------------------------------ 3.4/43.6 MB 1.5 MB/s eta 0:00:27
#    --- ------------------------------------ 3.9/43.6 MB 1.5 MB/s eta 0:00:26
#    --- ------------------------------------ 4.2/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.5/43.6 MB 1.6 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/43.6 MB 1.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 5.2/43.6 MB 1.2 MB/s eta 0:00:31
#    ----- ---------------------------------- 6.3/43.6 MB 1.5 MB/s eta 0:00:26
#    ------ --------------------------------- 6.6/43.6 MB 1.4 MB/s eta 0:00:27
#    ------ --------------------------------- 6.8/43.6 MB 1.4 MB/s eta 0:00:27
#    ------ --------------------------------- 7.1/43.6 MB 1.4 MB/s eta 0:00:26
#    ------ --------------------------------- 7.1/43.6 MB 1.4 MB/s eta 0:00:26
#    ------ --------------------------------- 7.1/43.6 MB 1.4 MB/s eta 0:00:26
#    ------ --------------------------------- 7.1/43.6 MB 1.4 MB/s eta 0:00:26
#    ------- -------------------------------- 8.4/43.6 MB 1.4 MB/s eta 0:00:25
#    ------- -------------------------------- 8.7/43.6 MB 1.4 MB/s eta 0:00:25
#    -------- ------------------------------- 8.9/43.6 MB 1.4 MB/s eta 0:00:25
#    -------- ------------------------------- 9.4/43.6 MB 1.5 MB/s eta 0:00:24
#    --------- ------------------------------ 10.0/43.6 MB 1.5 MB/s eta 0:00:23
#    --------- ------------------------------ 10.2/43.6 MB 1.5 MB/s eta 0:00:23
#    --------- ------------------------------ 10.5/43.6 MB 1.5 MB/s eta 0:00:23
#    --------- ------------------------------ 10.5/43.6 MB 1.5 MB/s eta 0:00:23
#    --------- ------------------------------ 10.7/43.6 MB 1.5 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.0/43.6 MB 1.4 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.0/43.6 MB 1.4 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.0/43.6 MB 1.4 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.0/43.6 MB 1.4 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.0/43.6 MB 1.4 MB/s eta 0:00:23
#    ---------- ----------------------------- 11.5/43.6 MB 1.3 MB/s eta 0:00:25
#    ---------- ----------------------------- 11.8/43.6 MB 1.3 MB/s eta 0:00:25
#    ----------- ---------------------------- 12.3/43.6 MB 1.3 MB/s eta 0:00:24
#    ----------- ---------------------------- 12.6/43.6 MB 1.3 MB/s eta 0:00:24
#    ------------ --------------------------- 13.1/43.6 MB 1.4 MB/s eta 0:00:23
#    ------------ --------------------------- 13.1/43.6 MB 1.4 MB/s eta 0:00:23
#    ------------ --------------------------- 13.4/43.6 MB 1.3 MB/s eta 0:00:23
#    ------------ --------------------------- 13.4/43.6 MB 1.3 MB/s eta 0:00:23
#    ------------ --------------------------- 13.4/43.6 MB 1.3 MB/s eta 0:00:23
#    ------------ --------------------------- 13.6/43.6 MB 1.3 MB/s eta 0:00:24
#    ------------ --------------------------- 13.6/43.6 MB 1.3 MB/s eta 0:00:24
#    ------------ --------------------------- 14.2/43.6 MB 1.3 MB/s eta 0:00:24
#    ------------- -------------------------- 14.4/43.6 MB 1.3 MB/s eta 0:00:23
#    ------------- -------------------------- 14.9/43.6 MB 1.3 MB/s eta 0:00:22
#    ------------- -------------------------- 15.2/43.6 MB 1.3 MB/s eta 0:00:22
#    -------------- ------------------------- 15.5/43.6 MB 1.3 MB/s eta 0:00:22
#    -------------- ------------------------- 16.0/43.6 MB 1.3 MB/s eta 0:00:21
#    -------------- ------------------------- 16.3/43.6 MB 1.3 MB/s eta 0:00:21
#    --------------- ------------------------ 16.5/43.6 MB 1.3 MB/s eta 0:00:21
#    --------------- ------------------------ 16.8/43.6 MB 1.3 MB/s eta 0:00:21
#    --------------- ------------------------ 17.0/43.6 MB 1.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 17.6/43.6 MB 1.3 MB/s eta 0:00:20
#    ---------------- ----------------------- 17.8/43.6 MB 1.3 MB/s eta 0:00:20
#    ---------------- ----------------------- 18.1/43.6 MB 1.3 MB/s eta 0:00:20
#    ----------------- ---------------------- 18.6/43.6 MB 1.3 MB/s eta 0:00:19
#    ----------------- ---------------------- 18.9/43.6 MB 1.4 MB/s eta 0:00:19
#    ----------------- ---------------------- 19.4/43.6 MB 1.4 MB/s eta 0:00:18
#    ------------------ --------------------- 19.7/43.6 MB 1.4 MB/s eta 0:00:18
#    ------------------ --------------------- 19.9/43.6 MB 1.4 MB/s eta 0:00:18
#    ------------------ --------------------- 20.2/43.6 MB 1.4 MB/s eta 0:00:18
#    ------------------ --------------------- 20.4/43.6 MB 1.4 MB/s eta 0:00:17
#    ------------------ --------------------- 20.4/43.6 MB 1.4 MB/s eta 0:00:17
#    ------------------ --------------------- 20.4/43.6 MB 1.4 MB/s eta 0:00:17
#    ------------------ --------------------- 20.4/43.6 MB 1.4 MB/s eta 0:00:17
#    ------------------ --------------------- 20.4/43.6 MB 1.4 MB/s eta 0:00:17
#    ------------------- -------------------- 21.0/43.6 MB 1.3 MB/s eta 0:00:18
#    ------------------- -------------------- 21.5/43.6 MB 1.3 MB/s eta 0:00:17
#    ------------------- -------------------- 21.8/43.6 MB 1.3 MB/s eta 0:00:17
#    -------------------- ------------------- 22.8/43.6 MB 1.4 MB/s eta 0:00:16
#    --------------------- ------------------ 23.1/43.6 MB 1.4 MB/s eta 0:00:16
#    --------------------- ------------------ 23.6/43.6 MB 1.4 MB/s eta 0:00:15
#    --------------------- ------------------ 23.9/43.6 MB 1.4 MB/s eta 0:00:15
#    ---------------------- ----------------- 24.4/43.6 MB 1.4 MB/s eta 0:00:14
#    ---------------------- ----------------- 24.6/43.6 MB 1.4 MB/s eta 0:00:14
#    ---------------------- ----------------- 24.9/43.6 MB 1.4 MB/s eta 0:00:14
#    ----------------------- ---------------- 25.7/43.6 MB 1.4 MB/s eta 0:00:13
#    ----------------------- ---------------- 26.0/43.6 MB 1.4 MB/s eta 0:00:13
#    ------------------------ --------------- 26.5/43.6 MB 1.4 MB/s eta 0:00:13
#    ------------------------ --------------- 26.7/43.6 MB 1.4 MB/s eta 0:00:12
#    ------------------------ --------------- 27.0/43.6 MB 1.4 MB/s eta 0:00:12
#    ------------------------- -------------- 27.5/43.6 MB 1.4 MB/s eta 0:00:12
#    ------------------------- -------------- 28.0/43.6 MB 1.4 MB/s eta 0:00:11
#    ------------------------- -------------- 28.3/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.6/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.6/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.8/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.8/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.8/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.8/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 28.8/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 29.1/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 29.4/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 29.4/43.6 MB 1.4 MB/s eta 0:00:11
#    -------------------------- ------------- 29.4/43.6 MB 1.4 MB/s eta 0:00:11
#    --------------------------- ------------ 30.4/43.6 MB 1.4 MB/s eta 0:00:10
#    --------------------------- ------------ 30.4/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 30.7/43.6 MB 1.4 MB/s eta 0:00:10
#    ---------------------------- ----------- 31.5/43.6 MB 1.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ----------------------------- ---------- 32.0/43.6 MB 1.3 MB/s eta 0:00:09
#    ------------------------------ --------- 33.6/43.6 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.1/43.6 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.1/43.6 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.3/43.6 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.6/43.6 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.9/43.6 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 35.1/43.6 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 35.1/43.6 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 35.1/43.6 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 35.1/43.6 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 35.4/43.6 MB 1.2 MB/s eta 0:00:07
#    --------------------------------- ------ 36.2/43.6 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 36.4/43.6 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 36.4/43.6 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 36.4/43.6 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 36.4/43.6 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 36.4/43.6 MB 1.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.2/43.6 MB 1.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 37.5/43.6 MB 1.1 MB/s eta 0:00:06
#    ---------------------------------- ----- 38.0/43.6 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 38.5/43.6 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 38.8/43.6 MB 1.1 MB/s eta 0:00:05
#    ----------------------------------- ---- 39.1/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.3/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.3/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.3/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.3/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.8/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------ --- 39.8/43.6 MB 1.1 MB/s eta 0:00:04
#    ------------------------------------- -- 40.4/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.6/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.6/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------- -- 40.9/43.6 MB 1.1 MB/s eta 0:00:03
#    -------------------------------------- - 41.7/43.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 42.2/43.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 42.2/43.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 42.2/43.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 42.2/43.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 42.2/43.6 MB 1.0 MB/s eta 0:00:02
#    ---------------------------------------  43.0/43.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  43.5/43.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 43.6/43.6 MB 1.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.1 threadpoolctl-3.5.0

# %%
# Code for Testing
import sklearn
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=0)
X = [[1, 2, 3], [11, 12, 13]]
y = [0, 1]
clf.fit(X, y)
print(clf.predict([[4, 5, 6], [14, 15, 16]]))
# Out:
# [0 1]

# %% [markdown]
# # Load Dataset from iris

# %%
from sklearn.datasets import load_iris #buil-in Dataset of Scikit learn
idata=load_iris()
X = idata.data #Features(sepal length,sepal width,petal length,petal width)
y = idata.target # Labels (species of iris)

# %% [markdown]
# # Preprocess the Data

# %%
from sklearn.preprocessing import StandardScaler
# Standardize the features(mean=0, variance=1)
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
StandardScaler()
# Out:
# StandardScaler()

# %% [markdown]
# # Split The Data

# %%
from sklearn.model_selection import train_test_split
# split data into 70% for train and 30% for testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Choose The Model

# %%
'''Classification: KNeighborsClassifier, LogisticRegression, RandomForestClassifier.

Regression: LinearRegression, Ridge, Lasso.

Clustering: KMeans, DBSCAN.'''
# Out:
# 'Classification: KNeighborsClassifier, LogisticRegression, RandomForestClassifier.\n\nRegression: LinearRegression, Ridge, Lasso.\n\nClustering: KMeans, DBSCAN.'

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier with 3 neighbors

knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn # there is three neighbors
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Train The Model

# %%
knn.fit(X_train, y_train) #fit the model for trianing
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Evaluate the Model

# %%
# evaluate the model’s performance - Accuracy And Mean Squared Error (MSE)

from sklearn.metrics import accuracy_score
# Make Prediction on the test set

y_prediction=knn.predict(X_test)

# And Calculate the Accuracy
accuracy=accuracy_score(y_test, y_prediction)
print(f'Accuracy: {accuracy:.2f}')

# 1.0 = 100% Accuracy and 0.63 = 63% Accuracy
# Out:
# Accuracy: 1.00

# %% [markdown]
# # Tune the Model

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameters to tune 
param_grid = {'n_neighbors':[3,5,7,9]}

# Perform Grid Search
grid_search = GridSearchCV(knn,param_grid,cv=5)
grid_search.fit(X_train, y_train)

# Best Parameters
print("Best Parameters: ",grid_search.best_params_)
# Out:
# Best Parameters:  {'n_neighbors': 3}

# %% [markdown]
# # Advance Concepts

# %% [markdown]
# ## PipeLines

# %%
# Combinne preprocessing and modeling into a single pipeline for cleaner code.

from sklearn.pipeline import Pipeline

#Create a pipeline

pipeline = Pipeline([('scaler',StandardScaler()),
                    ('knn',KNeighborsClassifier())])

# Train the Pipeline

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])

# %% [markdown]
# ## Cross-Validation

# %%
# Evaluate the model’s performance more robustly using cross-validation.

from sklearn.model_selection import cross_val_score

# perform 5- fold cross-validation

scores = cross_val_score(knn, X, y, cv=5)
print("Cross-Validaton Score : ",scores)
# Out:
# Cross-Validaton Score :  [0.96666667 0.96666667 0.93333333 0.96666667 1.        ]

# %% [markdown]
# ## Dimensionality Reduction

# %%
# Reduce the number of features using techniques like PCA (Principal Component Analysis).

from sklearn.decomposition import PCA

#reduce to 2 components

pca = PCA(n_components=2)
X_reduced=pca.fit_transform(X)

# %%
X_reduced
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
#        [-2.46882007,  0.13095149],
#        [-2.56231991,  0.36771886],
#        [-2.63953472,  0.31203998],
#        [-2.63198939, -0.19696122],
#        [-2.58739848, -0.20431849],
#        [-2.4099325 ,  0.41092426],
#        [-2.64886233,  0.81336382],
#        [-2.59873675,  1.09314576],
#        [-2.63692688, -0.12132235],
#        [-2.86624165,  0.06936447],
#        [-2.62523805,  0.59937002],
#        [-2.80068412,  0.26864374],
#        [-2.98050204, -0.48795834],
#        [-2.59000631,  0.22904384],
#        [-2.77010243,  0.26352753],
#        [-2.84936871, -0.94096057],
#        [-2.99740655, -0.34192606],
#        [-2.40561449,  0.18887143],
#        [-2.20948924,  0.43666314],
#        [-2.71445143, -0.2502082 ],
#        [-2.53814826,  0.50377114],
#        [-2.83946217, -0.22794557],
#        [-2.54308575,  0.57941002],
#        [-2.70335978,  0.10770608],
#        [ 1.28482569,  0.68516047],
#        [ 0.93248853,  0.31833364],
#        [ 1.46430232,  0.50426282],
#        [ 0.18331772, -0.82795901],
#        [ 1.08810326,  0.07459068],
#        [ 0.64166908, -0.41824687],
#        [ 1.09506066,  0.28346827],
#        [-0.74912267, -1.00489096],
#        [ 1.04413183,  0.2283619 ],
#        [-0.0087454 , -0.72308191],
#        [-0.50784088, -1.26597119],
#        [ 0.51169856, -0.10398124],
#        [ 0.26497651, -0.55003646],
#        [ 0.98493451, -0.12481785],
#        [-0.17392537, -0.25485421],
#        [ 0.92786078,  0.46717949],
#        [ 0.66028376, -0.35296967],
#        [ 0.23610499, -0.33361077],
#        [ 0.94473373, -0.54314555],
#        [ 0.04522698, -0.58383438],
#        [ 1.11628318, -0.08461685],
#        [ 0.35788842, -0.06892503],
#        [ 1.29818388, -0.32778731],
#        [ 0.92172892, -0.18273779],
#        [ 0.71485333,  0.14905594],
#        [ 0.90017437,  0.32850447],
#        [ 1.33202444,  0.24444088],
#        [ 1.55780216,  0.26749545],
#        [ 0.81329065, -0.1633503 ],
#        [-0.30558378, -0.36826219],
#        [-0.06812649, -0.70517213],
#        [-0.18962247, -0.68028676],
#        [ 0.13642871, -0.31403244],
#        [ 1.38002644, -0.42095429],
#        [ 0.58800644, -0.48428742],
#        [ 0.80685831,  0.19418231],
#        [ 1.22069088,  0.40761959],
#        [ 0.81509524, -0.37203706],
#        [ 0.24595768, -0.2685244 ],
#        [ 0.16641322, -0.68192672],
#        [ 0.46480029, -0.67071154],
#        [ 0.8908152 , -0.03446444],
#        [ 0.23054802, -0.40438585],
#        [-0.70453176, -1.01224823],
#        [ 0.35698149, -0.50491009],
#        [ 0.33193448, -0.21265468],
#        [ 0.37621565, -0.29321893],
#        [ 0.64257601,  0.01773819],
#        [-0.90646986, -0.75609337],
#        [ 0.29900084, -0.34889781],
#        [ 2.53119273, -0.00984911],
#        [ 1.41523588, -0.57491635],
#        [ 2.61667602,  0.34390315],
#        [ 1.97153105, -0.1797279 ],
#        [ 2.35000592, -0.04026095],
#        [ 3.39703874,  0.55083667],
#        [ 0.52123224, -1.19275873],
#        [ 2.93258707,  0.3555    ],
#        [ 2.32122882, -0.2438315 ],
#        [ 2.91675097,  0.78279195],
#        [ 1.66177415,  0.24222841],
#        [ 1.80340195, -0.21563762],
#        [ 2.1655918 ,  0.21627559],
#        [ 1.34616358, -0.77681835],
#        [ 1.58592822, -0.53964071],
#        [ 1.90445637,  0.11925069],
#        [ 1.94968906,  0.04194326],
#        [ 3.48705536,  1.17573933],
#        [ 3.79564542,  0.25732297],
#        [ 1.30079171, -0.76114964],
#        [ 2.42781791,  0.37819601],
#        [ 1.19900111, -0.60609153],
#        [ 3.49992004,  0.4606741 ],
#        [ 1.38876613, -0.20439933],
#        [ 2.2754305 ,  0.33499061],
#        [ 2.61409047,  0.56090136],
#        [ 1.25850816, -0.17970479],
#        [ 1.29113206, -0.11666865],
#        [ 2.12360872, -0.20972948],
#        [ 2.38800302,  0.4646398 ],
#        [ 2.84167278,  0.37526917],
#        [ 3.23067366,  1.37416509],
#        [ 2.15943764, -0.21727758],
#        [ 1.44416124, -0.14341341],
#        [ 1.78129481, -0.49990168],
#        [ 3.07649993,  0.68808568],
#        [ 2.14424331,  0.1400642 ],
#        [ 1.90509815,  0.04930053],
#        [ 1.16932634, -0.16499026],
#        [ 2.10761114,  0.37228787],
#        [ 2.31415471,  0.18365128],
#        [ 1.9222678 ,  0.40920347],
#        [ 1.41523588, -0.57491635],
#        [ 2.56301338,  0.2778626 ],
#        [ 2.41874618,  0.3047982 ],
#        [ 1.94410979,  0.1875323 ],
#        [ 1.52716661, -0.37531698],
#        [ 1.76434572,  0.07885885],
#        [ 1.90094161,  0.11662796],
#        [ 1.39018886, -0.28266094]])

# %% [markdown]
# ## Ensemble Methods
